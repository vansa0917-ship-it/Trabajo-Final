# %%
Estudiantes = {}


def agregar_estudiante():
def buscar_estudiante():
def modificar_ Notas():
def cancelacion():   
def resultados():
def informe():
def Salir():

print("\n--- Menu Principal ---")
print("1.Agregar estudiante")
nombre = input("Ingrese el nombre del estudiante a buscar: ")
