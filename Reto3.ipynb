# %% [markdown]
# Importancion de la base de datos

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('airlines.csv')
df.head(10)
# Out:
#    Airline ID                                          Name Alias IATA ICAO  \
# 0          -1                                       Unknown    \N    -  NaN
# 1           1                                Private flight    \N    -  NaN
# 2           2                                   135 Airways    \N  NaN  GNL
# 3           3                                 1Time Airline    \N   1T  RNX
# 4           4  2 Sqn No 1 Elementary Flying Training School    \N  NaN  WYT
# 5           5                               213 Flight Unit    \N  NaN  TFU
# 6           6                 223 Flight Unit State Airline    \N  NaN  CHD
# 7           7                             224th Flight Unit    \N  NaN  TTF
# 8           8                                   247 Jet Ltd    \N  NaN  TWF
# 9           9                                   3D Aviation    \N  NaN  SEC
#
#          Callsign         Country Active
# 0              \N              \N      Y
# 1             NaN             NaN      Y
# 2         GENERAL   United States      N
# 3         NEXTIME    South Africa      Y
# 4             NaN  United Kingdom      N
# 5             NaN          Russia      N
# 6  CHKALOVSK-AVIA          Russia      N
# 7      CARGO UNIT          Russia      N
# 8    CLOUD RUNNER  United Kingdom      N
# 9         SECUREX   United States      N

# %% [markdown]
# Informacion General

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6162 entries, 0 to 6161
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Airline ID  6162 non-null   int64
#  1   Name        6162 non-null   object
#  2   Alias       5656 non-null   object
#  3   IATA        1535 non-null   object
#  4   ICAO        6075 non-null   object
#  5   Callsign    5354 non-null   object
#  6   Country     6147 non-null   object
#  7   Active      6162 non-null   object
# dtypes: int64(1), object(7)
# memory usage: 385.3+ KB

# %%
df.describe().T
# Out:
#              count         mean          std  min      25%     50%      75%  \
# Airline ID  6162.0  4152.723304  4507.307094 -1.0  1541.25  3082.5  4628.75
#
#                 max
# Airline ID  21317.0

# %% [markdown]
# Buscar valores nulos

# %%
df.isnull().sum()
# Out:
# Airline ID       0
# Name             0
# Alias          506
# IATA          4627
# ICAO            87
# Callsign       808
# Country         15
# Active           0
# dtype: int64

# %%
(df.isnull().sum() / len(df)) * 100
# Out:
# Airline ID     0.000000
# Name           0.000000
# Alias          8.211620
# IATA          75.089257
# ICAO           1.411879
# Callsign      13.112626
# Country        0.243427
# Active         0.000000
# dtype: float64

# %% [markdown]
# Eliminar duplicados

# %%
print("Duplicados Antes:", df.duplicated().sum())

df = df.drop_duplicates()

print("Duplicados Después:", df.duplicated().sum())
# Out:
# Duplicados Antes: 0
# Duplicados Después: 0

# %% [markdown]
# Eliminar nulos

# %%
df = df.dropna()
df.isnull().sum()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1010 entries, 3 to 6161
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Airline ID  1010 non-null   int64
#  1   Name        1010 non-null   object
#  2   Alias       1010 non-null   object
#  3   IATA        1010 non-null   object
#  4   ICAO        1010 non-null   object
#  5   Callsign    1010 non-null   object
#  6   Country     1010 non-null   object
#  7   Active      1010 non-null   object
# dtypes: int64(1), object(7)
# memory usage: 71.0+ KB
